# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
pprint(establishments.find_one())
# Out:
# {'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.821311183521,
#  'FHRSID': 647177,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6PY',
#  'RatingDate': '2014-03-31T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6594bc3452744d25466ddcb2'),
#  'geocode': {'latitude': 51.086058, 'longitude': 1.196408},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/647177',
# ...

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene':{'$eq': 20}}
hygiene_results= establishments.find(query)
# Use count_documents to display the number of documents in the result
print(f'{db.establishments.count_documents(query)} documents')
# Display the first document in the results using pprint
for i in range(1):
    pprint(hygiene_results[i])
# Out:
# 41 documents
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6594bc3452744d25466df7e5'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
# ...

# %%
import pandas as pd

# %%
# Convert the result to a Pandas DataFrame
query = {'scores.Hygiene':{'$eq': 20}}
hygiene_results= establishments.find(query)
hygiene_results_df= pd.DataFrame(hygiene_results)
# Display the number of rows in the DataFrame
print(f'{len(hygiene_results_df)}rows')
# Display the first 10 rows of the DataFrame
hygiene_results_df.head(10)
# Out:
# 41rows
#                         _id   FHRSID  ChangesByServerID  \
# 0  6594bc3452744d25466df7e5   110681                  0
# 1  6594bc3452744d25466dfb6b   612039                  0
# 2  6594bc3452744d25466dfe71   730933                  0
# 3  6594bc3452744d25466e005f   172735                  0
# 4  6594bc3452744d25466e006d   172953                  0
# 5  6594bc3452744d25466e0a0e   512854                  0
# 6  6594bc3452744d25466e0c2f  1537089                  0
# 7  6594bc3452744d25466e2158   155648                  0
# 8  6594bc3452744d25466e259b  1012883                  0
# 9  6594bc3452744d25466e2db0   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.821311183521,
#  'FHRSID': 647177,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6PY',
#  'RatingDate': '2014-03-31T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6594bc3452744d25466ddcb2'),
#  'geocode': {'latitude': 51.086058, 'longitude': 1.196408},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/647177',
# ...

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {'LocalAuthorityName':{'$regex':"London"}, 'RatingValue':{'$gte':4}}
rating_results= establishments.find(query)
# Use count_documents to display the number of documents in the result
print(f'{db.establishments.count_documents(query)} documents')
# Display the first document in the results using pprint
for result in rating_results:
    pprint(result)
# Out:
# 33 documents
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6594bc3452744d25466e1202'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
# ...

# %%
# Convert the result to a Pandas DataFrame
query = {'LocalAuthorityName':{'$regex':"London"}, 'RatingValue':{'$gte':4}}
rating_results= establishments.find(query)
rating_df= pd.DataFrame(rating_results)
# Display the number of rows in the DataFrame
print(f'{len(rating_df)} rows')
# Display the first 10 rows of the DataFrame
rating_df.head(10)
# Out:
# 33 rows
#                         _id   FHRSID  ChangesByServerID  \
# 0  6594bc3452744d25466e1202   621707                  0
# 1  6594bc3452744d25466e1522  1130836                  0
# 2  6594bc3452744d25466e2085   293783                  0
# 3  6594bc3452744d25466e2e72  1315095                  0
# 4  6594bc3452744d25466e2e82   294474                  0
# 5  6594bc3452744d25466e3580   294900                  0
# 6  6594bc3552744d25466e5688   293756                  0
# 7  6594bc3552744d25466e5a5b   878523                  0
# 8  6594bc3552744d25466e5a68   293772                  0
# 9  6594bc3552744d25466e5a69   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000036464  Coombs Catering t/a The Lock and Key
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
#searching business to have as reference for analysis
query= {'BusinessName':'Penang Flavours'}
pprint(db.establishments.find_one(query))
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RatingValue': None,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6594bfface2eb920be969323'),
#  'geocode': {'latitude': 51.490142, 'longitude': 0.08384},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = {'geocode.latitude':51.490142}
longitude = {'geocode.longitude':0.08384}
limit= 5

query = {'RatingValue': '5', 
         'geocode.latitude': {'$lte': (latitude + degree_search), '$gte': (latitude - degree_search)}, 
         'geocode.longitude': {'$lte': (longitude + degree_search), '$gte': (longitude - degree_search)} 
         }

sort =  [{('scores.Hygiene',1)}]

# Print the results
top_five_results= (list(establishments.find(query).sort(sort).limit(limit)))
pprint(top_five_results)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 11
#       7 longitude = {'geocode.longitude':0.08384}
#       8 limit= 5
#      10 query = {'RatingValue': '5',
# ---> 11          'geocode.latitude': {'$lte': (latitude + degree_search), '$gte': (latitude - degree_search)},
#      12          'geocode.longitude': {'$lte': (longitude + degree_search), '$gte': (longitude - degree_search)}
#      13          }
#      15 sort =  [{('scores.Hygiene',1)}]
#      17 # Print the results
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'float'

# %%
# Convert result to Pandas DataFrame
top_five_df= pd.DataFrame(top_five_results)

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
match_query= {'$match':{'scores.Hygiene': 0}}
group_query= {'$group': {'_id':'$LocalAuthorityName'}}
sort_values= {'$sort': {'count':1}}
pipeline=[match_query, group_query,sort_values]
pipeline_results = list(establishments.aggregate(pipeline))
# Print the number of documents in the result
print("Number of documents in result: ", len(pipeline_results))
# Print the first 10 results
pprint(pipeline_results[0:10])
# Out:
# Number of documents in result:  55
# [{'_id': 'Eastbourne'},
#  {'_id': 'City of London Corporation'},
#  {'_id': 'Kensington and Chelsea'},
#  {'_id': 'Newham'},
#  {'_id': 'Chelmsford'},
#  {'_id': 'Tower Hamlets'},
#  {'_id': 'Thanet'},
#  {'_id': 'East Suffolk'},
#  {'_id': 'Tonbridge and Malling'},
#  {'_id': 'Castle Point'}]

# %%
# Convert the result to a Pandas DataFrame
hygiene_zero_df= pd.DataFrame(pipeline_results)
# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(hygiene_zero_df))

# Display the first 10 rows of the DataFrame
hygiene_zero_df.head(10)
# Out:
# Rows in DataFrame:  55
#                           _id
# 0                  Eastbourne
# 1  City of London Corporation
# 2      Kensington and Chelsea
# 3                      Newham
# 4                  Chelmsford
# 5               Tower Hamlets
# 6                      Thanet
# 7                East Suffolk
# 8       Tonbridge and Malling
# 9                Castle Point
